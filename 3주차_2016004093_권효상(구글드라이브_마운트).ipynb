# %% [markdown]
# <a href="https://colab.research.google.com/github/HyosangKwon/Data-analysis_with_mr/blob/main/3%EC%A3%BC%EC%B0%A8_2016004093_%EA%B6%8C%ED%9A%A8%EC%83%81(%EA%B5%AC%EA%B8%80%EB%93%9C%EB%9D%BC%EC%9D%B4%EB%B8%8C_%EB%A7%88%EC%9A%B4%ED%8A%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #데이터 프레임

# %% [markdown]
# ### 데이터 입력해 데이터 프레임 만들기

# %%
import pandas as pd

df = pd.DataFrame({'name'   : ['김지훈','이유진','박동현','김민지'],
                   'english': [90,80,60,70],
                   'math'   : [50,60,100,20]})
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %% [markdown]
# ### 특정 변수의 값 추출하기

# %%
df['english']
# Out:
# 0    90
# 1    80
# 2    60
# 3    70
# Name: english, dtype: int64

# %% [markdown]
# ### 변수의 값으로 합계 구하기

# %%
sum(df['english'])
# Out:
# 300

# %%
sum(df['math'])
# Out:
# 230

# %% [markdown]
# ### 변수의 값으로 평균 구하기

# %%
sum(df['english']) / len(df)
# Out:
# 75.0

# %% [markdown]
# ### 혼자해보기

# %%
df2 = pd.DataFrame({'제품': ['사과','딸기','수박'],
                    '가격': [1800,1500,3000],
                    '판매량': [24,38,13]})
df2
# Out:
#    제품    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
# 가격 평균
sum(df2['가격'])/len(df2)
# Out:
# 2100.0

# %%
# 판매량 평균
sum(df2['판매량'])/len(df2)
# Out:
# 25.0

# %% [markdown]
# # 외부 데이터 이용하기

# %%
# 구글 드라이브에 있는 csv파일 가져오기

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_exam = pd.read_excel('/content/drive/MyDrive/Data/excel_exam.xlsx')
df_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_exam_novar = pd.read_excel('/content/drive/MyDrive/Data/excel_exam_novar.xlsx')
df_exam_novar
# Out:
#    1  1.1  50  98  50.1
# 0  2    1  60  97    60
# 1  3    2  25  80    65
# 2  4    2  50  89    98
# 3  5    3  20  98    15
# 4  6    3  50  98    45
# 5  7    4  46  98    65
# 6  8    4  48  87    12

# %%
df_exam_novar = pd.read_excel('/content/drive/MyDrive/Data/excel_exam_novar.xlsx', header = None)
df_exam_novar
# Out:
#    0  1   2   3   4
# 0  1  1  50  98  50
# 1  2  1  60  97  60
# 2  3  2  25  80  65
# 3  4  2  50  89  98
# 4  5  3  20  98  15
# 5  6  3  50  98  45
# 6  7  4  46  98  65
# 7  8  4  48  87  12

# %%
df_csv_exam = pd.read_csv("/content/drive/MyDrive/Data/exam.csv")
df_csv_exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df_midterm = pd.DataFrame({'english':[90,80,60,70],
                           'math'   :[50,60,100,20],
                           'nclass'  :[1,2,2,2]})
df_midterm
# Out:
#    english  math  nclass
# 0       90    50       1
# 1       80    60       2
# 2       60   100       2
# 3       70    20       2

# %% [markdown]
# ### CSV파일로 저장하기

# %%
# .to_csv 함수의 경로에 '구글 드라이브 경로/파일명.csv'

df_midterm.to_csv('/content/drive/MyDrive/Data/output_newdata.csv')

# 인덱스 번호 제외하고 싶다면 index 속성 False로 (index = False)
